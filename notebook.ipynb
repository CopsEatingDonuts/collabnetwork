# %%
import pandas as pd
import numpy as np
import requests
from pybtex.database import parse_string #pip install pybtex

# %%
scientists = pd.read_excel('DataScientists.xls')

# %%
scientists.head()
# Out:
#                    name        country  \
# 0          aaron elmore  united states
# 1   abdalghani abujabal        germany
# 2          abdul quamar  united states
# 3     abdulhakim qahtan    netherlands
# 4  abhijnan chakraborty        germany
#
#                                  institution  \
# 0                      university of chicago
# 1                               amazon alexa
# 2                       ibm research almaden
# 3                         utrecht university
# 4  max planck institute for software systems
#
#                                                 dblp  expertise
# 0       https://dblp.org/pers/e/Elmore:Aaron_J=.html        NaN
# 1   https://dblp.org/pers/a/Abujabal:Abdalghani.html        NaN
# 2          https://dblp.org/pers/q/Quamar:Abdul.html        NaN
# 3                 https://dblp.org/pid/121/4198.html        NaN
# 4  https://dblp.org/pers/c/Chakraborty:Abhijnan.html        NaN

# %%
scientists.shape
# Out:
# (1220, 5)

# %%
duplicate_frame = pd.DataFrame(columns = scientists.columns)

for i in range(0, len(scientists[scientists.duplicated(subset='dblp')])):
    duplicate = scientists[scientists.duplicated(subset='dblp')].iloc[i]['dblp']
    small_frame = scientists[scientists['dblp'] == duplicate]
    duplicate_frame = pd.concat([duplicate_frame, small_frame])

# %%
duplicate_frame
# Out:
#                  name        country  \
# 7     abolfazl asudeh  united states
# 8     abolfazl asudeh  united states
# 15      alfons kemper        germany
# 16      alfons kemper        germany
# 24        alon halevy  united states
# ...               ...            ...
# 1200     zechao shang  united states
# 1209      zhongle xie          china
# 1210      zhongle xie          china
# 1216       zoi kaoudi          qatar
# 1217       zoi kaoudi        germany
#
#                                          institution  \
# 7                  university of illinois at chicago
# 8                             university of michifan
# 15                    technical university of munich
# 16                                         tu munich
# 24                                          facebook
# ...                                              ...
# 1200                            univesity of chicago
# 1209  nus ai innovation and commercialisation center
# 1210                             zhejiang university
# 1216              qatar computing research institute
# 1217                                       tu berlin
#
#                                                    dblp expertise
# 7                     https://dblp.org/pid/04/7892.html       NaN
# 8                     https://dblp.org/pid/04/7892.html       NaN
# 15             https://dblp.org/pid/k/AlfonsKemper.html       NaN
# 16             https://dblp.org/pid/k/AlfonsKemper.html       NaN
# 24    https://dblp.uni-trier.de/pers/h/Halevy:Alon_Y...       NaN
# ...                                                 ...       ...
# 1200          https://dblp.org/pers/s/Shang:Zechao.html       NaN
# 1209                 https://dblp.org/pid/169/3419.html       NaN
# 1210                 https://dblp.org/pid/169/3419.html       NaN
# 1216            https://dblp.org/pers/k/Kaoudi:Zoi.html       NaN
# 1217            https://dblp.org/pers/k/Kaoudi:Zoi.html       NaN
#
# [306 rows x 5 columns]

# %%
scientists.drop_duplicates(subset='dblp', inplace=True, ignore_index=True) #remove duplicates by url

# %%
scientists.shape
# Out:
# (1079, 5)

# %%
url = scientists.iloc[4]['dblp']
bib = url[:-4] + 'bib'
r = requests.get(bib).text
bib_response = parse_string(r, 'bibtex')

# %%
len(bib_response.entries.keys()) #number of publications
# Out:
# 76

# %%
list(bib_response.entries.keys()) #list of publications
# Out:
# ['DBLP:conf/aaai/SinghKC24',
#  'DBLP:journals/corr/abs-2402-12759',
#  'DBLP:journals/corr/abs-2402-18502',
#  'DBLP:journals/tcss/DashC00G23',
#  'DBLP:journals/tkde/AliBCMGS23',
#  'DBLP:conf/ecom/Bansal0C23',
#  'DBLP:conf/fat/SinghDC23',
#  'DBLP:conf/sigir/ChhikaraG0C23',
#  'DBLP:conf/www/GuptaNCVRNDC23',
#  'DBLP:journals/corr/abs-2312-11280',
#  'DBLP:journals/tcss/BabaeiKCRCG22',
#  'DBLP:journals/tweb/BiswasPGGC22',
#  'DBLP:conf/aaai/GuptaYNCRB22',
#  'DBLP:conf/icde/AliBCMGS22',
#  'DBLP:conf/ijcai/NairYGCRB22',
#  'DBLP:conf/www/PatroJCGG22',
#  'DBLP:conf/www/DashC00G22',
#  'DBLP:journals/corr/abs-2201-01180',
#  'DBLP:journals/corr/abs-2202-03934',
#  'DBLP:journals/corr/abs-2203-08849',
#  'DBLP:journals/corr/abs-2204-00241',
#  'DBLP:journals/corr/abs-2204-12062',
#  'DBLP:journals/corr/abs-2204-12552',
#  'DBLP:journals/corr/abs-2205-03530',
#  'DBLP:conf/fat/DashC00G21',
#  'DBLP:conf/www/MotaMDGC21',
#  'DBLP:journals/corr/abs-2101-12406',
#  'DBLP:journals/corr/abs-2102-00141',
#  'DBLP:journals/pacmhci/MotaCBGH20',
#  'DBLP:conf/aaai/PatroCGG20',
#  'DBLP:conf/atal/StoicaCDG20',
#  'DBLP:conf/bigdataconf/BanerjeePDC20',
#  'DBLP:conf/bigdataconf/ShandilyaDCG020',
#  'DBLP:conf/comad/ChakrabortyG20',
#  'DBLP:conf/recsys/PatroCBG20',
#  'DBLP:conf/www/PatroBGGC20',
#  'DBLP:journals/corr/abs-2002-10764',
#  'DBLP:journals/corr/abs-2010-14624',
#  'DBLP:journals/corr/abs-2011-07359',
#  'DBLP:journals/ir/ChakrabortyGGG19',
#  'DBLP:journals/pacmhci/DashSBGGC19',
#  'DBLP:journals/sigmobile/ChakrabortyG19',
#  'DBLP:journals/tcss/ChakrabortyGGG19',
#  'DBLP:conf/ecir/MullickGDGC19',
#  'DBLP:conf/fat/ChakrabortyPGGL19',
#  'DBLP:conf/fat/BabaeiCKRCG19',
#  'DBLP:conf/kdd/SuhrBZGC19',
#  'DBLP:conf/www/ChakrabortyMBGH19',
#  'DBLP:journals/corr/abs-1902-07946',
#  'DBLP:journals/corr/abs-1905-06618',
#  'DBLP:journals/corr/abs-1909-05583',
#  'DBLP:journals/corr/abs-1909-10005',
#  'DBLP:conf/aies/BabaeiKCBGW18',
#  'DBLP:conf/asunam/ChakrabortyG18',
#  'DBLP:conf/chi/Chakraborty18',
#  'DBLP:conf/icwsm/RibeiroHBCKBG18',
#  'DBLP:conf/www/ChakrabortyLSG18',
#  'DBLP:journals/corr/abs-1810-09147',
#  'DBLP:journals/corr/abs-1811-08690',
#  'DBLP:journals/pacmhci/ChakrabortySMG17',
#  'DBLP:conf/icwsm/ChakrabortyMBGG17',
#  'DBLP:conf/ijcai/SamantaDCG17',
#  'DBLP:conf/www/ChakrabortyGGG17',
#  'DBLP:journals/corr/ChakrabortyMBGG17',
#  'DBLP:journals/corr/abs-1708-00670',
#  'DBLP:journals/corr/abs-1709-02957',
#  'DBLP:conf/asunam/ChakrabortyPKG16',
#  'DBLP:conf/cscw/SikdarCKGCKPM16',
#  'DBLP:conf/icwsm/ChakrabortyGGG16',
#  'DBLP:journals/corr/ChakrabortyPKG16',
#  'DBLP:conf/pakdd/RudraCSDGG15',
#  'DBLP:conf/comsnets/ChakrabortyNPR14',
#  'DBLP:conf/asunam/ChakrabortyC13',
#  'DBLP:conf/mobicom/ChakrabortyNPR13',
#  'DBLP:conf/ht/ChakrabortyGG12',
#  'DBLP:conf/itsc/MandalSCRBB11']

# %%
list(bib_response.entries.items()) #attributes of publications
# Out:
# [('DBLP:conf/aaai/SinghKC24',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Towards Fairness in Online Service with {K} Servers and Its Application on Fair Food Delivery'),
#       ('booktitle', 'Thirty-Eighth {AAAI} Conference on Artificial Intelligence, {AAAI} 2024, Thirty-Sixth Conference on Innovative Applications of Artificial Intelligence, {IAAI} 2024, Fourteenth Symposium on Educational Advances in Artificial Intelligence, {EAAI} 2014, February 20-27, 2024, Vancouver, Canada'),
#       ('pages', '19929--19936'),
#       ('publisher', '{AAAI} Press'),
#       ('year', '2024'),
#       ('url', 'https:
#       //doi.org/10.1609/aaai.v38i18.29969'), ('doi', '10.1609/AAAI.V38I18.29969'),
#       ('timestamp', 'Wed, 27 Mar 2024 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/aaai/SinghKC24.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Singh, Daman Deep'), Person('Kumar, Amit'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Wooldridge, Michael J.'), Person('Dy, Jennifer G.'), Person('Natarajan, Sriraam')])]))),
#  ('DBLP:journals/corr/abs-2402-12759',
#   Entry('article',
#     fields=[
#       ('title', 'Towards Fair Allocation in Social Commerce Platforms'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2402.12759'),
#       ('year', '2024'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2402.12759'), ('doi', '10.48550/ARXIV.2402.12759'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2402.12759'),
#       ('timestamp', 'Thu, 21 Mar 2024 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2402-12759.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Gupta, Anjali'), Person('Nagori, Shreyans J.'), Person('Chakraborty, Abhijnan'), Person('Vaish, Rohit'), Person('Ranu, Sayan'), Person('Nadkarni, Prajit Prashant Sinai'), Person('Dasararaju, Narendra Varma'), Person('Chelliah, Muthusamy')])]))),
#  ('DBLP:journals/corr/abs-2402-18502',
#   Entry('article',
#     fields=[
#       ('title', "Few-Shot Fairness: Unveiling LLM's Potential for Fairness-Aware Classification"),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2402.18502'),
#       ('year', '2024'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2402.18502'), ('doi', '10.48550/ARXIV.2402.18502'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2402.18502'),
#       ('timestamp', 'Tue, 26 Mar 2024 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2402-18502.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chhikara, Garima'), Person('Sharma, Anurag'), Person('Ghosh, Kripabandhu'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/tcss/DashC00G23',
#   Entry('article',
#     fields=[
#       ('title', 'FaiRIR: Mitigating Exposure Bias From Related Item Recommendations in Two-Sided Platforms'),
#       ('journal', '{IEEE} Trans. Comput. Soc. Syst.'),
#       ('volume', '10'),
#       ('number', '3'),
#       ('pages', '1301--1313'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.1109/TCSS.2022.3164655'), ('doi', '10.1109/TCSS.2022.3164655'),
#       ('timestamp', 'Thu, 15 Jun 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/tcss/DashC00G23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/tkde/AliBCMGS23',
#   Entry('article',
#     fields=[
#       ('title', 'On the Fairness of Time-Critical Influence Maximization in Social Networks'),
#       ('journal', '{IEEE} Trans. Knowl. Data Eng.'),
#       ('volume', '35'),
#       ('number', '3'),
#       ('pages', '2875--2886'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.1109/TKDE.2021.3120561'), ('doi', '10.1109/TKDE.2021.3120561'),
#       ('timestamp', 'Thu, 27 Jul 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/tkde/AliBCMGS23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Ali, Junaid'), Person('Babaei, Mahmoudreza'), Person('Chakraborty, Abhijnan'), Person('Mirzasoleiman, Baharan'), Person('Gummadi, Krishna P.'), Person('Singla, Adish')])]))),
#  ('DBLP:conf/ecom/Bansal0C23',
#   Entry('inproceedings',
#     fields=[
#       ('title', "These Deals Won't Last! Longevity, Uniformity, and Bias in Product Badge Assignment in eCommerce Platforms"),
#       ('booktitle', 'Proceedings of the 2023 {SIGIR} Workshop on eCommerce co-located with the 46th International {ACM} {SIGIR} Conference on Research and Development in Information Retrieval {(SIGIR} 2023), Taipei, Taiwan, July 27, 2023'),
#       ('series', '{CEUR} Workshop Proceedings'),
#       ('volume', '3589'),
#       ('publisher', 'CEUR-WS.org'),
#       ('year', '2023'),
#       ('url', 'https://ceur-ws.org/Vol-3589/paper\\_12.pdf'),
#       ('timestamp', 'Tue, 02 Jan 2024 17:44:44 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/ecom/Bansal0C23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Bansal, Archit'), Person('Banerjee, Kunal'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Kallumadi, Surya'), Person('Kim, Yubin'), Person('King, Tracy Holloway'), Person('Malmasi, Shervin'), Person('de Rijke, Maarten'), Person('Tagliabue, Jacopo')])]))),
#  ('DBLP:conf/fat/SinghDC23',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'FairAssign: Stochastically Fair Driver Assignment in Gig Delivery Platforms'),
#       ('booktitle', 'Proceedings of the 2023 {ACM} Conference on Fairness, Accountability, and Transparency, FAccT 2023, Chicago, IL, USA, June 12-15, 2023'),
#       ('pages', '753--763'),
#       ('publisher', '{ACM}'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.1145/3593013.3594040'), ('doi', '10.1145/3593013.3594040'),
#       ('timestamp', 'Thu, 15 Jun 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/fat/SinghDC23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Singh, Daman Deep'), Person('Das, Syamantak'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:conf/sigir/ChhikaraG0C23',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Fairness for both Readers and Authors: Evaluating Summaries of User Generated Content'),
#       ('booktitle', 'Proceedings of the 46th International {ACM} {SIGIR} Conference on Research and Development in Information Retrieval, {SIGIR} 2023, Taipei, Taiwan, July 23-27, 2023'),
#       ('pages', '1996--2000'),
#       ('publisher', '{ACM}'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.1145/3539618.3591986'), ('doi', '10.1145/3539618.3591986'),
#       ('timestamp', 'Fri, 21 Jul 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/sigir/ChhikaraG0C23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chhikara, Garima'), Person('Ghosh, Kripabandhu'), Person('Ghosh, Saptarshi'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Chen, Hsin{-}Hsi'), Person('Duh, Wei{-}Jou (Edward)'), Person('Huang, Hen{-}Hsen'), Person('Kato, Makoto P.'), Person('Mothe, Josiane'), Person('Poblete, Barbara')])]))),
#  ('DBLP:conf/www/GuptaNCVRNDC23',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Towards Fair Allocation in Social Commerce Platforms'),
#       ('booktitle', 'Proceedings of the {ACM} Web Conference 2023, {WWW} 2023, Austin, TX, USA, 30 April 2023 - 4 May 2023'),
#       ('pages', '3744--3754'),
#       ('publisher', '{ACM}'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.1145/3543507.3583398'), ('doi', '10.1145/3543507.3583398'),
#       ('timestamp', 'Mon, 28 Aug 2023 21:17:10 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/GuptaNCVRNDC23.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Gupta, Anjali'), Person('Nagori, Shreyans J.'), Person('Chakraborty, Abhijnan'), Person('Vaish, Rohit'), Person('Ranu, Sayan'), Person('Nadkarni, Prajit Prashant Sinai'), Person('Dasararaju, Narendra Varma'), Person('Chelliah, Muthusamy')]), ('editor', [Person('Ding, Ying'), Person('Tang, Jie'), Person('Sequeda, Juan F.'), Person('Aroyo, Lora'), Person('Castillo, Carlos'), Person('Houben, Geert{-}Jan')])]))),
#  ('DBLP:journals/corr/abs-2312-11280',
#   Entry('article',
#     fields=[
#       ('title', 'Towards Fairness in Online Service with k Servers and its Application on Fair Food Delivery'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2312.11280'),
#       ('year', '2023'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2312.11280'), ('doi', '10.48550/ARXIV.2312.11280'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2312.11280'),
#       ('timestamp', 'Tue, 16 Jan 2024 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2312-11280.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Singh, Daman Deep'), Person('Kumar, Amit'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/tcss/BabaeiKCRCG22',
#   Entry('article',
#     fields=[
#       ('title', 'Analyzing Biases in Perception of Truth in News Stories and Their Implications for Fact Checking'),
#       ('journal', '{IEEE} Trans. Comput. Soc. Syst.'),
#       ('volume', '9'),
#       ('number', '3'),
#       ('pages', '839--850'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1109/TCSS.2021.3096038'), ('doi', '10.1109/TCSS.2021.3096038'),
#       ('timestamp', 'Mon, 13 Jun 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/tcss/BabaeiKCRCG22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Babaei, Mahmoudreza'), Person('Kulshrestha, Juhi'), Person('Chakraborty, Abhijnan'), Person('Redmiles, Elissa M.'), Person('Cha, Meeyoung'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/tweb/BiswasPGGC22',
#   Entry('article',
#     fields=[
#       ('title', 'Toward Fair Recommendation in Two-sided Platforms'),
#       ('journal', '{ACM} Trans. Web'),
#       ('volume', '16'),
#       ('number', '2'),
#       ('pages', '8:1--8:34'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1145/3503624'), ('doi', '10.1145/3503624'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/tweb/BiswasPGGC22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Biswas, Arpita'), Person('Patro, Gourab K.'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:conf/aaai/GuptaYNCRB22',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'FairFoody: Bringing In Fairness in Food Delivery'),
#       ('booktitle', 'Thirty-Sixth {AAAI} Conference on Artificial Intelligence, {AAAI} 2022, Thirty-Fourth Conference on Innovative Applications of Artificial Intelligence, {IAAI} 2022, The Twelveth Symposium on Educational Advances in Artificial Intelligence, {EAAI} 2022 Virtual Event, February 22 - March 1, 2022'),
#       ('pages', '11900--11907'),
#       ('publisher', '{AAAI} Press'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1609/aaai.v36i11.21447'), ('doi', '10.1609/AAAI.V36I11.21447'),
#       ('timestamp', 'Mon, 04 Sep 2023 12:29:24 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/aaai/GuptaYNCRB22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Gupta, Anjali'), Person('Yadav, Rahul'), Person('Nair, Ashish'), Person('Chakraborty, Abhijnan'), Person('Ranu, Sayan'), Person('Bagchi, Amitabha')])]))),
#  ('DBLP:conf/icde/AliBCMGS22',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'On the Fairness of Time-Critical Influence Maximization in Social Networks (Extended Abstract)'),
#       ('booktitle', '38th {IEEE} International Conference on Data Engineering, {ICDE} 2022, Kuala Lumpur, Malaysia, May 9-12, 2022'),
#       ('pages', '1541--1542'),
#       ('publisher', '{IEEE}'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1109/ICDE53745.2022.00147'), ('doi', '10.1109/ICDE53745.2022.00147'),
#       ('timestamp', 'Fri, 05 Aug 2022 16:24:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/icde/AliBCMGS22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Ali, Junaid'), Person('Babaei, Mahmoudreza'), Person('Chakraborty, Abhijnan'), Person('Mirzasoleiman, Baharan'), Person('Gummadi, Krishna P.'), Person('Singla, Adish')])]))),
#  ('DBLP:conf/ijcai/NairYGCRB22',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Gigs with Guarantees: Achieving Fair Wage for Food Delivery Workers'),
#       ('booktitle', 'Proceedings of the Thirty-First International Joint Conference on Artificial Intelligence, {IJCAI} 2022, Vienna, Austria, 23-29 July 2022'),
#       ('pages', '5122--5128'),
#       ('publisher', 'ijcai.org'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.24963/ijcai.2022/711'), ('doi', '10.24963/IJCAI.2022/711'),
#       ('timestamp', 'Wed, 27 Jul 2022 16:43:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/ijcai/NairYGCRB22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Nair, Ashish'), Person('Yadav, Rahul'), Person('Gupta, Anjali'), Person('Chakraborty, Abhijnan'), Person('Ranu, Sayan'), Person('Bagchi, Amitabha')]), ('editor', [Person('Raedt, Luc De')])]))),
#  ('DBLP:conf/www/PatroJCGG22',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Scheduling Virtual Conferences Fairly: Achieving Equitable Participant and Speaker Satisfaction'),
#       ('booktitle', "{WWW} '22: The {ACM} Web Conference 2022, Virtual Event, Lyon, France, April 25 - 29, 2022"),
#       ('pages', '2646--2656'),
#       ('publisher', '{ACM}'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1145/3485447.3512136'), ('doi', '10.1145/3485447.3512136'),
#       ('timestamp', 'Mon, 26 Jun 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/PatroJCGG22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Jana, Prithwish'), Person('Chakraborty, Abhijnan'), Person('Gummadi, Krishna P.'), Person('Ganguly, Niloy')]), ('editor', [Person("Laforest, Fr{\\'{e}}d{\\'{e}}rique"), Person('Troncy, Rapha{\\"{e}}l'), Person('Simperl, Elena'), Person('Agarwal, Deepak'), Person('Gionis, Aristides'), Person('Herman, Ivan'), Person("M{\\'{e}}dini, Lionel")])]))),
#  ('DBLP:conf/www/DashC00G22',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Alexa, in you, {I} trust! Fairness and Interpretability Issues in E-commerce Search through Smart Speakers'),
#       ('booktitle', "{WWW} '22: The {ACM} Web Conference 2022, Virtual Event, Lyon, France, April 25 - 29, 2022"),
#       ('pages', '3695--3705'),
#       ('publisher', '{ACM}'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.1145/3485447.3512265'), ('doi', '10.1145/3485447.3512265'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/DashC00G22.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')]), ('editor', [Person("Laforest, Fr{\\'{e}}d{\\'{e}}rique"), Person('Troncy, Rapha{\\"{e}}l'), Person('Simperl, Elena'), Person('Agarwal, Deepak'), Person('Gionis, Aristides'), Person('Herman, Ivan'), Person("M{\\'{e}}dini, Lionel")])]))),
#  ('DBLP:journals/corr/abs-2201-01180',
#   Entry('article',
#     fields=[
#       ('title', 'Towards Fair Recommendation in Two-Sided Platforms'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2201.01180'),
#       ('year', '2022'),
#       ('url', 'https://arxiv.org/abs/2201.01180'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2201.01180'),
#       ('timestamp', 'Mon, 10 Jan 2022 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2201-01180.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Biswas, Arpita'), Person('Patro, Gourab K.'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/corr/abs-2202-03934',
#   Entry('article',
#     fields=[
#       ('title', 'Alexa, in you, {I} trust! Fairness and Interpretability Issues in E-commerce Search through Smart Speakers'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2202.03934'),
#       ('year', '2022'),
#       ('url', 'https://arxiv.org/abs/2202.03934'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2202.03934'),
#       ('timestamp', 'Thu, 10 Feb 2022 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2202-03934.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/abs-2203-08849',
#   Entry('article',
#     fields=[
#       ('title', 'FairFoody: Bringing in Fairness in Food Delivery'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2203.08849'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2203.08849'), ('doi', '10.48550/ARXIV.2203.08849'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2203.08849'),
#       ('timestamp', 'Wed, 11 May 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2203-08849.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Gupta, Anjali'), Person('Yadav, Rahul'), Person('Nair, Ashish'), Person('Chakraborty, Abhijnan'), Person('Ranu, Sayan'), Person('Bagchi, Amitabha')])]))),
#  ('DBLP:journals/corr/abs-2204-00241',
#   Entry('article',
#     fields=[
#       ('title', 'FaiRIR: Mitigating Exposure Bias from Related Item Recommendations in Two-Sided Platforms'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2204.00241'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2204.00241'), ('doi', '10.48550/ARXIV.2204.00241'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2204.00241'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2204-00241.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/abs-2204-12062',
#   Entry('article',
#     fields=[
#       ('title', 'Scheduling Virtual Conferences Fairly: Achieving Equitable Participant and Speaker Satisfaction'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2204.12062'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2204.12062'), ('doi', '10.48550/ARXIV.2204.12062'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2204.12062'),
#       ('timestamp', 'Thu, 28 Apr 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2204-12062.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Jana, Prithwish'), Person('Chakraborty, Abhijnan'), Person('Gummadi, Krishna P.'), Person('Ganguly, Niloy')])]))),
#  ('DBLP:journals/corr/abs-2204-12552',
#   Entry('article',
#     fields=[
#       ('title', "These Deals Won't Last! Longevity, Uniformity and Bias in Product Badge Assignment in E-Commerce Platforms"),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2204.12552'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2204.12552'), ('doi', '10.48550/ARXIV.2204.12552'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2204.12552'),
#       ('timestamp', 'Thu, 28 Apr 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2204-12552.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Bansal, Archit'), Person('Banerjee, Kunal'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/corr/abs-2205-03530',
#   Entry('article',
#     fields=[
#       ('title', 'Gigs with Guarantees: Achieving Fair Wage for Food Delivery Workers'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2205.03530'),
#       ('year', '2022'),
#       ('url', 'https:
#       //doi.org/10.48550/arXiv.2205.03530'), ('doi', '10.48550/ARXIV.2205.03530'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2205.03530'),
#       ('timestamp', 'Wed, 11 May 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2205-03530.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Nair, Ashish'), Person('Yadav, Rahul'), Person('Gupta, Anjali'), Person('Chakraborty, Abhijnan'), Person('Ranu, Sayan'), Person('Bagchi, Amitabha')])]))),
#  ('DBLP:conf/fat/DashC00G21',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'When the Umpire is also a Player: Bias in Private Label Product Recommendations on E-commerce Marketplaces'),
#       ('booktitle', "FAccT '21: 2021 {ACM} Conference on Fairness, Accountability, and Transparency, Virtual Event / Toronto, Canada, March 3-10, 2021"),
#       ('pages', '873--884'),
#       ('publisher', '{ACM}'),
#       ('year', '2021'),
#       ('url', 'https:
#       //doi.org/10.1145/3442188.3445944'), ('doi', '10.1145/3442188.3445944'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/fat/DashC00G21.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')]), ('editor', [Person('Elish, Madeleine Clare'), Person('Isaac, William'), Person('Zemel, Richard S.')])]))),
#  ('DBLP:conf/www/MotaMDGC21',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Fair Partitioning of Public Resources: Redrawing District Boundary to Minimize Spatial Inequality in School Funding'),
#       ('booktitle', "{WWW} '21: The Web Conference 2021, Virtual Event / Ljubljana, Slovenia, April 19-23, 2021"),
#       ('pages', '646--657'),
#       ('publisher', '{ACM} / {IW3C2}'),
#       ('year', '2021'),
#       ('url', 'https:
#       //doi.org/10.1145/3442381.3450041'), ('doi', '10.1145/3442381.3450041'),
#       ('timestamp', 'Mon, 07 Jun 2021 12:37:30 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/MotaMDGC21.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Mota, Nuno'), Person('Mohammadi, Negar'), Person('Dey, Palash'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Leskovec, Jure'), Person('Grobelnik, Marko'), Person('Najork, Marc'), Person('Tang, Jie'), Person('Zia, Leila')])]))),
#  ('DBLP:journals/corr/abs-2101-12406',
#   Entry('article',
#     fields=[
#       ('title', "Fairness for Whom? Understanding the Reader's Perception of Fairness in Text Summarization"),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2101.12406'),
#       ('year', '2021'),
#       ('url', 'https://arxiv.org/abs/2101.12406'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2101.12406'),
#       ('timestamp', 'Tue, 02 Feb 2021 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2101-12406.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Shandilya, Anurag'), Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Kripabandhu'), Person('Ghosh, Saptarshi')])]))),
#  ('DBLP:journals/corr/abs-2102-00141',
#   Entry('article',
#     fields=[
#       ('title', 'When the Umpire is also a Player: Bias in Private Label Product Recommendations on E-commerce Marketplaces'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2102.00141'),
#       ('year', '2021'),
#       ('url', 'https://arxiv.org/abs/2102.00141'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2102.00141'),
#       ('timestamp', 'Tue, 09 Feb 2021 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2102-00141.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/pacmhci/MotaCBGH20',
#   Entry('article',
#     fields=[
#       ('title', 'On the Desiderata for Online Altruism: Nudging for Equitable Donations'),
#       ('journal', 'Proc. {ACM} Hum. Comput. Interact.'),
#       ('volume', '4'),
#       ('number', '{CSCW2}'),
#       ('pages', '126:1--126:21'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1145/3415197'), ('doi', '10.1145/3415197'),
#       ('timestamp', 'Tue, 10 Nov 2020 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/pacmhci/MotaCBGH20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Mota, Nuno'), Person('Chakraborty, Abhijnan'), Person('Biega, Asia J.'), Person('Gummadi, Krishna P.'), Person('Heidari, Hoda')])]))),
#  ('DBLP:conf/aaai/PatroCGG20',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Fair Updates in Two-Sided Market Platforms: On Incrementally Updating Recommendations'),
#       ('booktitle', 'The Thirty-Fourth {AAAI} Conference on Artificial Intelligence, {AAAI} 2020, The Thirty-Second Innovative Applications of Artificial Intelligence Conference, {IAAI} 2020, The Tenth {AAAI} Symposium on Educational Advances in Artificial Intelligence, {EAAI} 2020, New York, NY, USA, February 7-12, 2020'),
#       ('pages', '181--188'),
#       ('publisher', '{AAAI} Press'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1609/aaai.v34i01.5349'), ('doi', '10.1609/AAAI.V34I01.5349'),
#       ('timestamp', 'Mon, 04 Sep 2023 12:29:24 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/aaai/PatroCGG20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Chakraborty, Abhijnan'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:conf/atal/StoicaCDG20',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Minimizing Margin of Victory for Fair Political and Educational Districting'),
#       ('booktitle', "Proceedings of the 19th International Conference on Autonomous Agents and Multiagent Systems, {AAMAS} '20, Auckland, New Zealand, May 9-13, 2020"),
#       ('pages', '1305--1313'),
#       ('publisher', 'International Foundation for Autonomous Agents and Multiagent Systems'),
#       ('year', '2020'),
#       ('url', 'https://dl.acm.or
#       g/doi/10.5555/3398761.3398912'), ('doi', '10.5555/3398761.3398912'),
#       ('timestamp', 'Tue, 26 Jul 2022 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/atal/StoicaCDG20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Stoica, Ana{-}Andreea'), Person('Chakraborty, Abhijnan'), Person('Dey, Palash'), Person('Gummadi, Krishna P.')]), ('editor', [Person('Seghrouchni, Amal El Fallah'), Person('Sukthankar, Gita'), Person('An, Bo'), Person('Yorke{-}Smith, Neil')])]))),
#  ('DBLP:conf/bigdataconf/BanerjeePDC20',
#   Entry('inproceedings',
#     fields=[
#       ('title', "Analyzing 'Near Me' Services: Potential for Exposure Bias in Location-based Retrieval"),
#       ('booktitle', '2020 {IEEE} International Conference on Big Data {(IEEE} BigData 2020), Atlanta, GA, USA, December 10-13, 2020'),
#       ('pages', '3642--3651'),
#       ('publisher', '{IEEE}'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1109/BigData50022.2020.9378476'), ('doi', '10.1109/BIGDATA50022.2020.9378476'),
#       ('timestamp', 'Fri, 19 Nov 2021 16:08:20 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/bigdataconf/BanerjeePDC20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Banerjee, Ashmi'), Person('Patro, Gourab K.'), Person('Dietz, Linus W.'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Wu, Xintao'), Person('Jermaine, Chris'), Person('Xiong, Li'), Person('Hu, Xiaohua'), Person('Kotevska, Olivera'), Person('Lu, Siyuan'), Person('Xu, Weija'), Person('Aluru, Srinivas'), Person('Zhai, Chengxiang'), Person('Al{-}Masri, Eyhab'), Person('Chen, Zhiyuan'), Person('Saltz, Jeff')])]))),
#  ('DBLP:conf/bigdataconf/ShandilyaDCG020',
#   Entry('inproceedings',
#     fields=[
#       ('title', "Fairness for Whom? Understanding the Reader's Perception of Fairness in Text Summarization"),
#       ('booktitle', '2020 {IEEE} International Conference on Big Data {(IEEE} BigData 2020), Atlanta, GA, USA, December 10-13, 2020'),
#       ('pages', '3692--3701'),
#       ('publisher', '{IEEE}'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1109/BigData50022.2020.9378095'), ('doi', '10.1109/BIGDATA50022.2020.9378095'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/bigdataconf/ShandilyaDCG020.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Shandilya, Anurag'), Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Kripabandhu'), Person('Ghosh, Saptarshi')]), ('editor', [Person('Wu, Xintao'), Person('Jermaine, Chris'), Person('Xiong, Li'), Person('Hu, Xiaohua'), Person('Kotevska, Olivera'), Person('Lu, Siyuan'), Person('Xu, Weija'), Person('Aluru, Srinivas'), Person('Zhai, Chengxiang'), Person('Al{-}Masri, Eyhab'), Person('Chen, Zhiyuan'), Person('Saltz, Jeff')])]))),
#  ('DBLP:conf/comad/ChakrabortyG20',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Fairness in Algorithmic Decision Making'),
#       ('booktitle', 'CoDS-COMAD 2020: 7th {ACM} {IKDD} CoDS and 25th COMAD, Hyderabad India, January 5-7, 2020'),
#       ('pages', '367--368'),
#       ('publisher', '{ACM}'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1145/3371158.3371234'), ('doi', '10.1145/3371158.3371234'),
#       ('timestamp', 'Wed, 22 Jan 2020 14:32:27 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/comad/ChakrabortyG20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Gummadi, Krishna P.')]), ('editor', [Person('Roy, Rishiraj Saha')])]))),
#  ('DBLP:conf/recsys/PatroCBG20',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Towards Safety and Sustainability: Designing Local Recommendations for Post-pandemic World'),
#       ('booktitle', 'RecSys 2020: Fourteenth {ACM} Conference on Recommender Systems, Virtual Event, Brazil, September 22-26, 2020'),
#       ('pages', '358--367'),
#       ('publisher', '{ACM}'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1145/3383313.3412251'), ('doi', '10.1145/3383313.3412251'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/recsys/PatroCBG20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Chakraborty, Abhijnan'), Person('Banerjee, Ashmi'), Person('Ganguly, Niloy')]), ('editor', [Person('Santos, Rodrygo L. T.'), Person('Marinho, Leandro Balby'), Person('Daly, Elizabeth M.'), Person('Chen, Li'), Person('Falk, Kim'), Person('Koenigstein, Noam'), Person('de Moura, Edleno Silva')])]))),
#  ('DBLP:conf/www/PatroBGGC20',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'FairRec: Two-Sided Fairness for Personalized Recommendations in Two-Sided Platforms'),
#       ('booktitle', "{WWW} '20: The Web Conference 2020, Taipei, Taiwan, April 20-24, 2020"),
#       ('pages', '1194--1204'),
#       ('publisher', '{ACM} / {IW3C2}'),
#       ('year', '2020'),
#       ('url', 'https:
#       //doi.org/10.1145/3366423.3380196'), ('doi', '10.1145/3366423.3380196'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/PatroBGGC20.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Biswas, Arpita'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Huang, Yennun'), Person('King, Irwin'), Person('Liu, Tie{-}Yan'), Person('van Steen, Maarten')])]))),
#  ('DBLP:journals/corr/abs-2002-10764',
#   Entry('article',
#     fields=[
#       ('title', 'FairRec: Two-Sided Fairness for Personalized Recommendations in Two-Sided Platforms'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2002.10764'),
#       ('year', '2020'),
#       ('url', 'https://arxiv.org/abs/2002.10764'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2002.10764'),
#       ('timestamp', 'Tue, 03 Mar 2020 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2002-10764.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Biswas, Arpita'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/corr/abs-2010-14624',
#   Entry('article',
#     fields=[
#       ('title', 'On Fair Virtual Conference Scheduling: Achieving Equitable Participant and Speaker Satisfaction'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2010.14624'),
#       ('year', '2020'),
#       ('url', 'https://arxiv.org/abs/2010.14624'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2010.14624'),
#       ('timestamp', 'Mon, 02 Nov 2020 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2010-14624.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Patro, Gourab K.'), Person('Chakraborty, Abhijnan'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/abs-2011-07359',
#   Entry('article',
#     fields=[
#       ('title', "Analyzing 'Near Me' Services: Potential for Exposure Bias in Location-based Retrieval"),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/2011.07359'),
#       ('year', '2020'),
#       ('url', 'https://arxiv.org/abs/2011.07359'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '2011.07359'),
#       ('timestamp', 'Wed, 18 Nov 2020 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-2011-07359.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Banerjee, Ashmi'), Person('Patro, Gourab K.'), Person('Dietz, Linus W.'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/ir/ChakrabortyGGG19',
#   Entry('article',
#     fields=[
#       ('title', 'Optimizing the recency-relevance-diversity trade-offs in non-personalized news recommendations'),
#       ('journal', 'Inf. Retr. J.'),
#       ('volume', '22'),
#       ('number', '5'),
#       ('pages', '447--475'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1007/s10791-019-09351-2'), ('doi', '10.1007/S10791-019-09351-2'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/ir/ChakrabortyGGG19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/pacmhci/DashSBGGC19',
#   Entry('article',
#     fields=[
#       ('title', 'Summarizing User-generated Textual Content: Motivation and Methods for Fairness in Algorithmic Summaries'),
#       ('journal', 'Proc. {ACM} Hum. Comput. Interact.'),
#       ('volume', '3'),
#       ('number', '{CSCW}'),
#       ('pages', '172:1--172:28'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3359274'), ('doi', '10.1145/3359274'),
#       ('timestamp', 'Sat, 30 Sep 2023 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/pacmhci/DashSBGGC19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Shandilya, Anurag'), Person('Biswas, Arindam'), Person('Ghosh, Kripabandhu'), Person('Ghosh, Saptarshi'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/sigmobile/ChakrabortyG19',
#   Entry('article',
#     fields=[
#       ('title', 'Online Social Networks to Foster Long-Term Welfare'),
#       ('journal', 'GetMobile Mob. Comput. Commun.'),
#       ('volume', '23'),
#       ('number', '2'),
#       ('pages', '5--8'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3372300.3372302'), ('doi', '10.1145/3372300.3372302'),
#       ('timestamp', 'Fri, 06 Mar 2020 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/sigmobile/ChakrabortyG19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ganguly, Niloy')])]))),
#  ('DBLP:journals/tcss/ChakrabortyGGG19',
#   Entry('article',
#     fields=[
#       ('title', 'Editorial Versus Audience Gatekeeping: Analyzing News Selection and Consumption Dynamics in Online News Media'),
#       ('journal', '{IEEE} Trans. Comput. Soc. Syst.'),
#       ('volume', '6'),
#       ('number', '4'),
#       ('pages', '680--691'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1109/TCSS.2019.2920000'), ('doi', '10.1109/TCSS.2019.2920000'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/tcss/ChakrabortyGGG19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:conf/ecir/MullickGDGC19',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Public Sphere 2.0: Targeted Commenting in Online News Media'),
#       ('booktitle', 'Advances in Information Retrieval - 41st European Conference on {IR} Research, {ECIR} 2019, Cologne, Germany, April 14-18, 2019, Proceedings, Part {II}'),
#       ('series', 'Lecture Notes in Computer Science'),
#       ('volume', '11438'),
#       ('pages', '180--187'),
#       ('publisher', 'Springer'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1007/978-3-030-15719-7\\_23'), ('doi', '10.1007/978-3-030-15719-7\\_23'),
#       ('timestamp', 'Mon, 28 Aug 2023 21:17:41 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/ecir/MullickGDGC19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Mullick, Ankan'), Person('Ghosh, Sayan'), Person('Dutt, Ritam'), Person('Ghosh, Avijit'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Azzopardi, Leif'), Person('Stein, Benno'), Person('Fuhr, Norbert'), Person('Mayr, Philipp'), Person('Hauff, Claudia'), Person('Hiemstra, Djoerd')])]))),
#  ('DBLP:conf/fat/ChakrabortyPGGL19',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Equality of Voice: Towards Fair Representation in Crowdsourced Top-K Recommendations'),
#       ('booktitle', 'Proceedings of the Conference on Fairness, Accountability, and Transparency, FAT* 2019, Atlanta, GA, USA, January 29-31, 2019'),
#       ('pages', '129--138'),
#       ('publisher', '{ACM}'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3287560.3287570'), ('doi', '10.1145/3287560.3287570'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/fat/ChakrabortyPGGL19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Patro, Gourab K.'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.'), Person('Loiseau, Patrick')]), ('editor', [Person('danah boyd'), Person('Morgenstern, Jamie H.')])]))),
#  ('DBLP:conf/fat/BabaeiCKRCG19',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Analyzing Biases in Perception of Truth in News Stories and Their Implications for Fact Checking'),
#       ('booktitle', 'Proceedings of the Conference on Fairness, Accountability, and Transparency, FAT* 2019, Atlanta, GA, USA, January 29-31, 2019'),
#       ('pages', '139'),
#       ('publisher', '{ACM}'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3287560.3287581'), ('doi', '10.1145/3287560.3287581'),
#       ('timestamp', 'Wed, 27 Feb 2019 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/fat/BabaeiCKRCG19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Babaei, Mahmoudreza'), Person('Chakraborty, Abhijnan'), Person('Kulshrestha, Juhi'), Person('Redmiles, Elissa M.'), Person('Cha, Meeyoung'), Person('Gummadi, Krishna P.')]), ('editor', [Person('danah boyd'), Person('Morgenstern, Jamie H.')])]))),
#  ('DBLP:conf/kdd/SuhrBZGC19',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Two-Sided Fairness for Repeated Matchings in Two-Sided Markets: {A} Case Study of a Ride-Hailing Platform'),
#       ('booktitle', 'Proceedings of the 25th {ACM} {SIGKDD} International Conference on Knowledge Discovery {\\&} Data Mining, {KDD} 2019, Anchorage, AK, USA, August 4-8, 2019'),
#       ('pages', '3082--3092'),
#       ('publisher', '{ACM}'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3292500.3330793'), ('doi', '10.1145/3292500.3330793'),
#       ('timestamp', 'Tue, 16 Aug 2022 23:04:27 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/kdd/SuhrBZGC19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('S{\\"{u}}hr, Tom'), Person('Biega, Asia J.'), Person('Zehlike, Meike'), Person('Gummadi, Krishna P.'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Teredesai, Ankur'), Person('Kumar, Vipin'), Person('Li, Ying'), Person("Rosales, R{\\'{o}}mer"), Person('Terzi, Evimaria'), Person('Karypis, George')])]))),
#  ('DBLP:conf/www/ChakrabortyMBGH19',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'On the Impact of Choice Architectures on Inequality in Online Donation Platforms'),
#       ('booktitle', 'The World Wide Web Conference, {WWW} 2019, San Francisco, CA, USA, May 13-17, 2019'),
#       ('pages', '2623--2629'),
#       ('publisher', '{ACM}'),
#       ('year', '2019'),
#       ('url', 'https:
#       //doi.org/10.1145/3308558.3313663'), ('doi', '10.1145/3308558.3313663'),
#       ('timestamp', 'Sun, 22 Sep 2019 18:12:47 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/ChakrabortyMBGH19.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Mota, Nuno'), Person('Biega, Asia J.'), Person('Gummadi, Krishna P.'), Person('Heidari, Hoda')]), ('editor', [Person('Liu, Ling'), Person('White, Ryen W.'), Person('Mantrach, Amin'), Person('Silvestri, Fabrizio'), Person('McAuley, Julian J.'), Person('Baeza{-}Yates, Ricardo'), Person('Zia, Leila')])]))),
#  ('DBLP:journals/corr/abs-1902-07946',
#   Entry('article',
#     fields=[
#       ('title', 'Public Sphere 2.0: Targeted Commenting in Online News Media'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1902.07946'),
#       ('year', '2019'),
#       ('url', 'http://arxiv.org/abs/1902.07946'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1902.07946'),
#       ('timestamp', 'Thu, 23 May 2019 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-1902-07946.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Mullick, Ankan'), Person('Ghosh, Sayan'), Person('Dutt, Ritam'), Person('Ghosh, Avijit'), Person('Chakraborty, Abhijnan')])]))),
#  ('DBLP:journals/corr/abs-1905-06618',
#   Entry('article',
#     fields=[
#       ('title', 'On the Fairness of Time-Critical Influence Maximization in Social Networks'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1905.06618'),
#       ('year', '2019'),
#       ('url', 'http://arxiv.org/abs/1905.06618'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1905.06618'),
#       ('timestamp', 'Fri, 15 Jan 2021 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-1905-06618.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Ali, Junaid'), Person('Babaei, Mahmoudreza'), Person('Chakraborty, Abhijnan'), Person('Mirzasoleiman, Baharan'), Person('Gummadi, Krishna P.'), Person('Singla, Adish')])]))),
#  ('DBLP:journals/corr/abs-1909-05583',
#   Entry('article',
#     fields=[
#       ('title', 'Minimizing Margin of Victory for Fair Political and Educational Districting'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1909.05583'),
#       ('year', '2019'),
#       ('url', 'http://arxiv.org/abs/1909.05583'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1909.05583'),
#       ('timestamp', 'Wed, 18 Sep 2019 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-1909-05583.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
# ...
#  ('DBLP:journals/pacmhci/ChakrabortySMG17',
#   Entry('article',
#     fields=[
#       ('title', 'Tabloids in the Era of Social Media?: Understanding the Production and Consumption of Clickbaits in Twitter'),
#       ('journal', 'Proc. {ACM} Hum. Comput. Interact.'),
#       ('volume', '1'),
#       ('number', '{CSCW}'),
#       ('pages', '30:1--30:21'),
#       ('year', '2017'),
#       ('url', 'https:
#       //doi.org/10.1145/3134665'), ('doi', '10.1145/3134665'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/pacmhci/ChakrabortySMG17.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Sarkar, Rajdeep'), Person('Mrigen, Ayushi'), Person('Ganguly, Niloy')])]))),
#  ('DBLP:conf/icwsm/ChakrabortyMBGG17',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Who Makes Trends? Understanding Demographic Biases in Crowdsourced Recommendations'),
#       ('booktitle', "Proceedings of the Eleventh International Conference on Web and Social Media, {ICWSM} 2017, Montr{\\'{e}}al, Qu{\\'{e}}bec, Canada, May 15-18, 2017"),
#       ('pages', '22--31'),
#       ('publisher', '{AAAI} Press'),
#       ('year', '2017'),
#       ('url', 'https://aaai.org/ocs/index.php/ICWSM/ICWSM17/paper/view/15680'),
#       ('timestamp', 'Tue, 24 Sep 2019 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/icwsm/ChakrabortyMBGG17.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Messias, Johnnatan'), Person("Benevenuto, Fabr{\\'{\\i}}cio"), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:conf/ijcai/SamantaDCG17',
#   Entry('inproceedings',
#     fields=[
#       ('title', '{LMPP:} {A} Large Margin Point Process Combining Reinforcement and Competition for Modeling Hashtag Popularity'),
#       ('booktitle', 'Proceedings of the Twenty-Sixth International Joint Conference on Artificial Intelligence, {IJCAI} 2017, Melbourne, Australia, August 19-25, 2017'),
#       ('pages', '2679--2685'),
#       ('publisher', 'ijcai.org'),
#       ('year', '2017'),
#       ('url', 'https:
#       //doi.org/10.24963/ijcai.2017/373'), ('doi', '10.24963/IJCAI.2017/373'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/ijcai/SamantaDCG17.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Samanta, Bidisha'), Person('De, Abir'), Person('Chakraborty, Abhijnan'), Person('Ganguly, Niloy')]), ('editor', [Person('Sierra, Carles')])]))),
#  ('DBLP:conf/www/ChakrabortyGGG17',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Optimizing the Recency-Relevancy Trade-off in Online News Recommendations'),
#       ('booktitle', 'Proceedings of the 26th International Conference on World Wide Web, {WWW} 2017, Perth, Australia, April 3-7, 2017'),
#       ('pages', '837--846'),
#       ('publisher', '{ACM}'),
#       ('year', '2017'),
#       ('url', 'https:
#       //doi.org/10.1145/3038912.3052656'), ('doi', '10.1145/3038912.3052656'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/www/ChakrabortyGGG17.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')]), ('editor', [Person('Barrett, Rick'), Person('Cummings, Rick'), Person('Agichtein, Eugene'), Person('Gabrilovich, Evgeniy')])]))),
#  ('DBLP:journals/corr/ChakrabortyMBGG17',
#   Entry('article',
#     fields=[
#       ('title', 'Who Makes Trends? Understanding Demographic Biases in Crowdsourced Recommendations'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1704.00139'),
#       ('year', '2017'),
#       ('url', 'http://arxiv.org/abs/1704.00139'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1704.00139'),
#       ('timestamp', 'Tue, 24 Sep 2019 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/ChakrabortyMBGG17.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Messias, Johnnatan'), Person("Benevenuto, Fabr{\\'{\\i}}cio"), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/abs-1708-00670',
#   Entry('article',
#     fields=[
#       ('title', 'On Quantifying Knowledge Segregation in Society'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1708.00670'),
#       ('year', '2017'),
#       ('url', 'http://arxiv.org/abs/1708.00670'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1708.00670'),
#       ('timestamp', 'Tue, 24 Sep 2019 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-1708-00670.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ali, Muhammad'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/abs-1709-02957',
#   Entry('article',
#     fields=[
#       ('title', 'Tabloids in the Era of Social Media? Understanding the Production and Consumption of Clickbaits in Twitter'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1709.02957'),
#       ('year', '2017'),
#       ('url', 'http://arxiv.org/abs/1709.02957'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1709.02957'),
#       ('timestamp', 'Mon, 13 Aug 2018 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/abs-1709-02957.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Sarkar, Rajdeep'), Person('Mrigen, Ayushi'), Person('Ganguly, Niloy')])]))),
#  ('DBLP:conf/asunam/ChakrabortyPKG16',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Stop Clickbait: Detecting and preventing clickbaits in online news media'),
#       ('booktitle', '2016 {IEEE/ACM} International Conference on Advances in Social Networks Analysis and Mining, {ASONAM} 2016, San Francisco, CA, USA, August 18-21, 2016'),
#       ('pages', '9--16'),
#       ('publisher', '{IEEE} Computer Society'),
#       ('year', '2016'),
#       ('url', 'https:
#       //doi.org/10.1109/ASONAM.2016.7752207'), ('doi', '10.1109/ASONAM.2016.7752207'),
#       ('timestamp', 'Fri, 24 Mar 2023 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/asunam/ChakrabortyPKG16.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Paranjape, Bhargavi'), Person('Kakarla, Sourya'), Person('Ganguly, Niloy')]), ('editor', [Person('Kumar, Ravi'), Person('Caverlee, James'), Person('Tong, Hanghang')])]))),
#  ('DBLP:conf/cscw/SikdarCKGCKPM16',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Identifying and Characterizing Sleeping Beauties on YouTube'),
#       ('booktitle', 'Proceedings of the 19th {ACM} Conference on Computer Supported Cooperative Work and Social Computing, {CSCW} 2015, San Francisco, CA, USA, February 27 - March 2, 2016, Companion Volume'),
#       ('pages', '405--408'),
#       ('publisher', '{ACM}'),
#       ('year', '2016'),
#       ('url', 'https:
#       //doi.org/10.1145/2818052.2869103'), ('doi', '10.1145/2818052.2869103'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/cscw/SikdarCKGCKPM16.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Sikdar, Sandipan'), Person('Chaudhary, Anshit E.'), Person('Kumar, Shraman'), Person('Ganguly, Niloy'), Person('Chakraborty, Abhijnan'), Person('Kumar, Gaurav'), Person('Patil, Abhijeet'), Person('Mukherjee, Animesh')]), ('editor', [Person('Gergle, Darren'), Person('Morris, Meredith Ringel'), Person('Bj{\\o}rn, Pernille'), Person('Konstan, Joseph A.')])]))),
#  ('DBLP:conf/icwsm/ChakrabortyGGG16',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Dissemination Biases of Social Media Channels: On the Topical Coverage of Socially Shared News'),
#       ('booktitle', 'Proceedings of the Tenth International Conference on Web and Social Media, Cologne, Germany, May 17-20, 2016'),
#       ('pages', '559--562'),
#       ('publisher', '{AAAI} Press'),
#       ('year', '2016'),
#       ('url', 'http://www.aaai.org/ocs/index.php/ICWSM/ICWSM16/paper/view/13131'),
#       ('timestamp', 'Fri, 05 Feb 2021 11:07:46 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/icwsm/ChakrabortyGGG16.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy'), Person('Gummadi, Krishna P.')])]))),
#  ('DBLP:journals/corr/ChakrabortyPKG16',
#   Entry('article',
#     fields=[
#       ('title', 'Stop Clickbait: Detecting and Preventing Clickbaits in Online News Media'),
#       ('journal', 'CoRR'),
#       ('volume', 'abs/1610.09786'),
#       ('year', '2016'),
#       ('url', 'http://arxiv.org/abs/1610.09786'),
#
#       ('eprinttype', 'arXiv'), ('eprint', '1610.09786'),
#       ('timestamp', 'Mon, 13 Aug 2018 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/journals/corr/ChakrabortyPKG16.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Paranjape, Bhargavi'), Person('Kakarla, Sourya'), Person('Ganguly, Niloy')])]))),
#  ('DBLP:conf/pakdd/RudraCSDGG15',
#   Entry('inproceedings',
#     fields=[
#       ('title', '{\\#}FewThingsAboutIdioms: Understanding Idioms and Its Users in the Twitter Online Social Network'),
#       ('booktitle', 'Advances in Knowledge Discovery and Data Mining - 19th Pacific-Asia Conference, {PAKDD} 2015, Ho Chi Minh City, Vietnam, May 19-22, 2015, Proceedings, Part {I}'),
#       ('series', 'Lecture Notes in Computer Science'),
#       ('volume', '9077'),
#       ('pages', '108--121'),
#       ('publisher', 'Springer'),
#       ('year', '2015'),
#       ('url', 'https:
#       //doi.org/10.1007/978-3-319-18038-0\\_9'), ('doi', '10.1007/978-3-319-18038-0\\_9'),
#       ('timestamp', 'Wed, 07 Dec 2022 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/pakdd/RudraCSDGG15.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Rudra, Koustav'), Person('Chakraborty, Abhijnan'), Person('Sethi, Manav'), Person('Das, Shreyasi'), Person('Ganguly, Niloy'), Person('Ghosh, Saptarshi')]), ('editor', [Person('Cao, Tru H.'), Person('Lim, Ee{-}Peng'), Person('Zhou, Zhi{-}Hua'), Person('Ho, Tu Bao'), Person('Cheung, David Wai{-}Lok'), Person('Motoda, Hiroshi')])]))),
#  ('DBLP:conf/comsnets/ChakrabortyNPR14',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'LoadSense: Passively estimating cellular load'),
#       ('booktitle', 'Sixth International Conference on Communication Systems and Networks, {COMSNETS} 2014, Bangalore, India, January 6-10, 2014'),
#       ('pages', '1--3'),
#       ('publisher', '{IEEE}'),
#       ('year', '2014'),
#       ('url', 'https:
#       //doi.org/10.1109/COMSNETS.2014.6734917'), ('doi', '10.1109/COMSNETS.2014.6734917'),
#       ('timestamp', 'Wed, 16 Oct 2019 14:14:51 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/comsnets/ChakrabortyNPR14.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Navda, Vishnu'), Person('Padmanabhan, Venkata N.'), Person('Ramjee, Ramachandran')])]))),
#  ('DBLP:conf/asunam/ChakrabortyC13',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'OverCite: finding overlapping communities in citation network'),
#       ('booktitle', "Advances in Social Networks Analysis and Mining 2013, {ASONAM} '13, Niagara, ON, Canada - August 25 - 29, 2013"),
#       ('pages', '1124--1131'),
#       ('publisher', '{ACM}'),
#       ('year', '2013'),
#       ('url', 'https:
#       //doi.org/10.1145/2492517.2500255'), ('doi', '10.1145/2492517.2500255'),
#       ('timestamp', 'Wed, 07 Dec 2022 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/asunam/ChakrabortyC13.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Tanmoy'), Person('Chakraborty, Abhijnan')]), ('editor', [Person('Rokne, Jon G.'), Person('Faloutsos, Christos')])]))),
#  ('DBLP:conf/mobicom/ChakrabortyNPR13',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Coordinating cellular background transfers using loadsense'),
#       ('booktitle', "The 19th Annual International Conference on Mobile Computing and Networking, MobiCom'13, Miami, FL, USA, September 30 - October 04, 2013"),
#       ('pages', '63--74'),
#       ('publisher', '{ACM}'),
#       ('year', '2013'),
#       ('url', 'https:
#       //doi.org/10.1145/2500423.2500447'), ('doi', '10.1145/2500423.2500447'),
#       ('timestamp', 'Tue, 06 Nov 2018 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/mobicom/ChakrabortyNPR13.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Navda, Vishnu'), Person('Padmanabhan, Venkata N.'), Person('Ramjee, Ramachandran')]), ('editor', [Person('Helal, Sumi'), Person('Chandra, Ranveer'), Person('Kravets, Robin')])]))),
#  ('DBLP:conf/ht/ChakrabortyGG12',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Detecting overlapping communities in folksonomies'),
#       ('booktitle', "23rd {ACM} Conference on Hypertext and Social Media, {HT} '12, Milwaukee, WI, USA, June 25-28, 2012"),
#       ('pages', '213--218'),
#       ('publisher', '{ACM}'),
#       ('year', '2012'),
#       ('url', 'https:
#       //doi.org/10.1145/2309996.2310032'), ('doi', '10.1145/2309996.2310032'),
#       ('timestamp', 'Thu, 14 Oct 2021 01:00:00 +0200'),
#       ('biburl', 'https://dblp.org/rec/conf/ht/ChakrabortyGG12.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Ganguly, Niloy')]), ('editor', [Person('Munson, Ethan V.'), Person('Strohmaier, Markus')])]))),
#  ('DBLP:conf/itsc/MandalSCRBB11',
#   Entry('inproceedings',
#     fields=[
#       ('title', 'Road traffic congestion monitoring and measurement using active {RFID} and {GSM} technology'),
#       ('booktitle', '14th International {IEEE} Conference on Intelligent Transportation Systems, {ITSC} 2011, Washington, DC, USA, October 5-7, 2011'),
#       ('pages', '1375--1379'),
#       ('publisher', '{IEEE}'),
#       ('year', '2011'),
#       ('url', 'https:
#       //doi.org/10.1109/ITSC.2011.6082954'), ('doi', '10.1109/ITSC.2011.6082954'),
#       ('timestamp', 'Fri, 27 Dec 2019 00:00:00 +0100'),
#       ('biburl', 'https://dblp.org/rec/conf/itsc/MandalSCRBB11.bib'),
#       ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#     persons=OrderedCaseInsensitiveDict([('author', [Person('Mandal, Koushik'), Person('Sen, Arindam'), Person('Chakraborty, Abhijnan'), Person('Roy, Siuli'), Person('Batabyal, Suvadip'), Person('Bandyopadhyay, Somprakash')])])))]

# %%
bib_response.entries[list(bib_response.entries.keys())[3]]
# Out:
# Entry('article',
#   fields=[
#     ('title', 'FaiRIR: Mitigating Exposure Bias From Related Item Recommendations in Two-Sided Platforms'),
#     ('journal', '{IEEE} Trans. Comput. Soc. Syst.'),
#     ('volume', '10'),
#     ('number', '3'),
#     ('pages', '1301--1313'),
#     ('year', '2023'),
#     ('url', 'https:
#     //doi.org/10.1109/TCSS.2022.3164655'), ('doi', '10.1109/TCSS.2022.3164655'),
#     ('timestamp', 'Thu, 15 Jun 2023 01:00:00 +0200'),
#     ('biburl', 'https://dblp.org/rec/journals/tcss/DashC00G23.bib'),
#     ('bibsource', 'dblp computer science bibliography, https://dblp.org')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])]))

# %%
bib_response.entries[list(bib_response.entries.keys())[3]].persons #list of authors on the paper
# Out:
# OrderedCaseInsensitiveDict([('author', [Person('Dash, Abhisek'), Person('Chakraborty, Abhijnan'), Person('Ghosh, Saptarshi'), Person('Mukherjee, Animesh'), Person('Gummadi, Krishna P.')])])
